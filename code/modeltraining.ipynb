# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv('dataset.csv')

# %%
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
dataset[:]
# Out:
#                  State          District          Crop  Season  Year  \
# 0       Andhra Pradesh          ADILABAD  Cotton(lint)  Kharif  1998
# 1       Andhra Pradesh         ANANTAPUR  Cotton(lint)  Kharif  1998
# 2       Andhra Pradesh     EAST GODAVARI  Cotton(lint)  Kharif  1998
# 3       Andhra Pradesh            GUNTUR  Cotton(lint)  Kharif  1998
# 4       Andhra Pradesh            KADAPA  Cotton(lint)  Kharif  1998
# ...                ...               ...           ...     ...   ...
# 340409     Uttarakhand       PITHORAGARH         Wheat    Rabi  2021
# 340410     Uttarakhand      RUDRA PRAYAG         Wheat    Rabi  2021
# 340411     Uttarakhand     TEHRI GARHWAL         Wheat    Rabi  2021
# 340412     Uttarakhand  UDAM SINGH NAGAR         Wheat    Rabi  2021
# 340413     Uttarakhand       UTTAR KASHI         Wheat    Rabi  2021
#
#             Area     Production     Yield
# 0       144900.0   14478.668450  0.458937
# 1         7300.0    2046.608773  1.287671
# 2         9800.0    5094.749500  2.387755
# 3       162300.0   94165.776012  2.664818
# 4        13400.0    3788.403474  1.298507
# ...          ...            ...       ...
# 340409   16850.0   28415.000000  1.686350
# 340410    9155.0    8709.000000  0.951283
# 340411   15451.0   28096.000000  1.818394
# 340412  105961.0  471000.000000  4.445032
# 340413    9082.0   15203.000000  1.673970
#
# [340414 rows x 8 columns]

# %%
# Out:
#                  State          District          Crop  Season     Production  \
# 0       Andhra Pradesh          ADILABAD  Cotton(lint)  Kharif   14478.668450
# 1       Andhra Pradesh         ANANTAPUR  Cotton(lint)  Kharif    2046.608773
# 2       Andhra Pradesh     EAST GODAVARI  Cotton(lint)  Kharif    5094.749500
# 3       Andhra Pradesh            GUNTUR  Cotton(lint)  Kharif   94165.776012
# 4       Andhra Pradesh            KADAPA  Cotton(lint)  Kharif    3788.403474
# ...                ...               ...           ...     ...            ...
# 340409     Uttarakhand       PITHORAGARH         Wheat    Rabi   28415.000000
# 340410     Uttarakhand      RUDRA PRAYAG         Wheat    Rabi    8709.000000
# 340411     Uttarakhand     TEHRI GARHWAL         Wheat    Rabi   28096.000000
# 340412     Uttarakhand  UDAM SINGH NAGAR         Wheat    Rabi  471000.000000
# 340413     Uttarakhand       UTTAR KASHI         Wheat    Rabi   15203.000000
#
#            Yield
# 0       0.458937
# 1       1.287671
# 2       2.387755
# 3       2.664818
# 4       1.298507
# ...          ...
# 340409  1.686350
# 340410  0.951283
# 340411  1.818394
# 340412  4.445032
# 340413  1.673970
#
# [340414 rows x 6 columns]

# %%
dataset.iloc[:,5:]
# Out:
#            Production     Yield
# 0        14478.668450  0.458937
# 1         2046.608773  1.287671
# 2         5094.749500  2.387755
# 3        94165.776012  2.664818
# 4         3788.403474  1.298507
# ...               ...       ...
# 340409   28415.000000  1.686350
# 340410    8709.000000  0.951283
# 340411   28096.000000  1.818394
# 340412  471000.000000  4.445032
# 340413   15203.000000  1.673970
#
# [340414 rows x 2 columns]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [0,1,2,3])], remainder='passthrough')
X = ct.fit_transform(X).toarray()

# %%
type(X_test)
# Out:
# numpy.ndarray

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 0)

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
regressor.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=0)

# %%
y_pred=regressor.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

mae = mean_absolute_error(y_test, y_pred)
print("MAE:", mae)

rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print("RMSE:", rmse)

r2 = r2_score(y_test, y_pred)
print("R²:", r2)
# Out:
# MAE: 9.332530385568257
# RMSE: 220.81791491136772
# R²: 0.9532387287803635

# %%
acc = []

for i in range(len(y_pred)):
  if (y_test[i]!=0) :
    acc.append(abs(1 - (y_pred[i]/y_test[i]) ))


print(sum(acc)/len(acc))
# Out:
# 0.045131174539092773

# %%
import pickle
filename = 'modelforyield.sav'
pickle.dump(regressor, open(filename, 'wb'))

# %%
filename = 'transformer.sav'
pickle.dump(ct, open(filename, 'wb'))
